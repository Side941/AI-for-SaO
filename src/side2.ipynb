# %%
# =========================
# Imports and Data
# =========================
import random
import copy
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load city coordinates
cities = pd.read_csv("data/cities.csv")
coords = cities[['X', 'Y']].values
N = len(coords)

# Compute distance matrix
dist_matrix = np.sqrt(((coords[:, None, :] - coords[None, :, :])**2).sum(axis=2))

# %%
# =========================
# Individual Representation
# =========================
class Individual:
    def __init__(self, gene):
        self.gene = gene
        self.fitness = 0

# =========================
# Fitness Function
# =========================
def total_distance(ind):
    route = ind.gene
    dist = sum(dist_matrix[route[i], route[i+1]] for i in range(len(route)-1))
    dist += dist_matrix[route[-1], route[0]]  # Return to start
    return dist

# =========================
# Selection (Tournament)
# =========================
def selection(population):
    P = len(population)
    new_pop = []
    for _ in range(P):
        i1, i2 = random.sample(range(P), 2)
        winner = population[i1] if population[i1].fitness < population[i2].fitness else population[i2]
        new_pop.append(copy.deepcopy(winner))
    return new_pop

# =========================
# Crossover (Ordered Crossover)
# =========================
def crossover(parents):
    P = len(parents)
    N = len(parents[0].gene)
    offspring = []
    for i in range(0, P, 2):
        p1, p2 = parents[i], parents[i+1]
        a, b = sorted(random.sample(range(N), 2))
        child1_gene = [None]*N
        child2_gene = [None]*N
        child1_gene[a:b] = p1.gene[a:b]
        child2_gene[a:b] = p2.gene[a:b]
        def fill_remaining(child, parent):
            parent_cities = [c for c in parent.gene if c not in child]
            return [c if c is not None else parent_cities.pop(0) for c in child]
        child1_gene = fill_remaining(child1_gene, p2)
        child2_gene = fill_remaining(child2_gene, p1)
        offspring.append(Individual(child1_gene))
        offspring.append(Individual(child2_gene))
    return offspring

# =========================
# Mutation (Swap)
# =========================
def mutation(offspring, MUTRATE=0.1):
    N = len(offspring[0].gene)
    for ind in offspring:
        if random.random() < MUTRATE:
            a, b = random.sample(range(N), 2)
            ind.gene[a], ind.gene[b] = ind.gene[b], ind.gene[a]
    return offspring

# %%
# =========================
# GA Parameters
# =========================
P = 100           # Population size
MUTRATE = 0.1     # Mutation rate
maxGeneration = 10000

# =========================
# Initialize Population
# =========================
population = []
for _ in range(P):
    gene = random.sample(range(N), N)
    ind = Individual(gene)
    ind.fitness = total_distance(ind)
    population.append(ind)

# =========================
# GA Main Loop
# =========================
bestFitness = []
averageFitness = []
worstFitness = []

start_time = time.time()

for gen in range(maxGeneration):
    offspring = selection(population)
    offspring = crossover(offspring)
    offspring = mutation(offspring, MUTRATE)
    
    for ind in offspring:
        ind.fitness = total_distance(ind)
    
    population = offspring
    best = min(population, key=lambda x: x.fitness)
    avg = np.mean([ind.fitness for ind in population])
    worst = max(population, key=lambda x: x.fitness)
    
    bestFitness.append(best.fitness)
    averageFitness.append(avg)
    worstFitness.append(worst.fitness)
    
    if gen % 50 == 0:
        print(f"Gen {gen}: Best = {best.fitness:.2f}, Average = {avg:.2f}, Worst = {worst.fitness:.2f}")

end_time = time.time()
computation_time = end_time - start_time

# =========================
# Display Results
# =========================
best_solution = min(population, key=lambda x: x.fitness)
print(f"\nBest route distance found: {best_solution.fitness:.2f}")
print("Best route:", best_solution.gene)
print(f"Computation time: {computation_time:.2f} seconds")

# =========================
# Plot GA Statistics
# =========================
plt.figure(figsize=(10,6))
plt.plot(bestFitness, label='Best Distance')
plt.plot(averageFitness, label='Average Distance')
plt.plot(worstFitness, label='Worst Distance')
plt.xlabel('Generation')
plt.ylabel('Distance')
plt.title('Genetic Algorithm for TSP')
plt.legend()
plt.grid(True)
plt.show()

# =========================
# Plot Best Route
# =========================
best_route = best_solution.gene + [best_solution.gene[0]]
x = [coords[i][0] for i in best_route]
y = [coords[i][1] for i in best_route]

plt.figure(figsize=(10,6))
plt.plot(x, y, marker='o', linestyle='-')
plt.title(f'Best TSP Route Found\nDistance: {best_solution.fitness:.2f}\nTime: {computation_time:.2f}s')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)

for i, city_index in enumerate(best_route[:-1]):
    plt.annotate(str(city_index), (coords[city_index][0], coords[city_index][1]),
                 textcoords="offset points", xytext=(5,5), fontsize=8, color='black')

first_city = best_route[0]
plt.scatter(coords[first_city][0], coords[first_city][1], color='red', s=120, zorder=5, label='Start')

second_city = best_route[1]
plt.arrow(coords[first_city][0], coords[first_city][1],
          coords[second_city][0] - coords[first_city][0],
          coords[second_city][1] - coords[first_city][1],
          color='green', width=0.002, head_width=0.03, length_includes_head=True, zorder=6)

plt.legend()
plt.show()

# =========================
# Save GA Results to Text File
# =========================
with open("ga_single_run_results.txt", "w") as f:
    f.write("Genetic Algorithm (GA) Single Run Results\n")
    f.write("=========================================\n\n")
    f.write(f"Population size: {P}\n")
    f.write(f"Mutation rate: {MUTRATE}\n")
    f.write(f"Generations: {maxGeneration}\n")
    f.write(f"Total computation time: {computation_time:.2f} seconds\n\n")

    f.write(f"Best route distance found: {best_solution.fitness:.2f}\n")
    f.write("Best route (city indices in order):\n")
    f.write(" -> ".join(map(str, best_solution.gene)) + "\n\n")

    f.write("Convergence Summary (every 50 generations):\n")
    f.write("-----------------------------------------\n")
    for i in range(0, maxGeneration, 50):
        if i < len(bestFitness):
            f.write(f"Gen {i:5d}: Best = {bestFitness[i]:.2f}, "
                    f"Avg = {averageFitness[i]:.2f}, "
                    f"Worst = {worstFitness[i]:.2f}\n")

print("\nGA results saved to ga_single_run_results.txt")
# Out:
# Gen 0: Best = 2169.03, Average = 2605.85, Worst = 2993.43
# Gen 50: Best = 1732.53, Average = 2101.25, Worst = 2416.89
# Gen 100: Best = 1635.12, Average = 1963.90, Worst = 2350.15
# Gen 150: Best = 1421.36, Average = 1719.27, Worst = 2072.45
# Gen 200: Best = 1040.80, Average = 1199.23, Worst = 1430.72
# Gen 250: Best = 978.68, Average = 998.51, Worst = 1316.41
# Gen 300: Best = 957.89, Average = 981.50, Worst = 1169.79
# Gen 350: Best = 952.78, Average = 962.55, Worst = 1230.89
# Gen 400: Best = 947.50, Average = 964.22, Worst = 1296.87
# Gen 450: Best = 931.36, Average = 956.56, Worst = 1208.56
# Gen 500: Best = 895.65, Average = 903.24, Worst = 1118.89
# Gen 550: Best = 891.29, Average = 902.86, Worst = 1380.92
# Gen 600: Best = 881.23, Average = 911.15, Worst = 1104.53
# Gen 650: Best = 871.45, Average = 888.10, Worst = 1122.09
# Gen 700: Best = 850.85, Average = 859.66, Worst = 1071.58
# Gen 750: Best = 804.13, Average = 832.27, Worst = 1095.39
# Gen 800: Best = 804.13, Average = 819.93, Worst = 1182.72
# Gen 850: Best = 804.13, Average = 818.17, Worst = 1077.45
# Gen 900: Best = 804.13, Average = 819.19, Worst = 1131.21
# Gen 950: Best = 804.13, Average = 816.35, Worst = 1117.81
# Gen 1000: Best = 804.13, Average = 816.57, Worst = 1173.95
# Gen 1050: Best = 804.13, Average = 814.58, Worst = 1069.33
# Gen 1100: Best = 804.13, Average = 831.55, Worst = 1101.45
# Gen 1150: Best = 804.13, Average = 816.40, Worst = 1144.61
# Gen 1200: Best = 804.13, Average = 817.15, Worst = 1094.49
# Gen 1250: Best = 804.13, Average = 819.63, Worst = 1134.73
# Gen 1300: Best = 804.13, Average = 820.89, Worst = 1148.37
# Gen 1350: Best = 804.13, Average = 828.82, Worst = 1097.80
# Gen 1400: Best = 804.13, Average = 822.37, Worst = 1117.40
# Gen 1450: Best = 804.13, Average = 826.43, Worst = 1117.06
# Gen 1500: Best = 803.63, Average = 835.04, Worst = 1214.18
# Gen 1550: Best = 803.63, Average = 814.03, Worst = 1078.81
# Gen 1600: Best = 803.63, Average = 819.53, Worst = 1048.89
# Gen 1650: Best = 802.76, Average = 825.12, Worst = 1104.90
# Gen 1700: Best = 802.76, Average = 825.88, Worst = 1077.94
# Gen 1750: Best = 802.76, Average = 820.33, Worst = 1044.31
# Gen 1800: Best = 802.76, Average = 818.92, Worst = 1123.03
# Gen 1850: Best = 802.76, Average = 824.31, Worst = 1167.96
# Gen 1900: Best = 802.76, Average = 821.68, Worst = 1108.60
# Gen 1950: Best = 802.76, Average = 825.93, Worst = 1141.72
# Gen 2000: Best = 802.76, Average = 822.76, Worst = 1222.58
# Gen 2050: Best = 802.76, Average = 820.77, Worst = 1146.86
# Gen 2100: Best = 802.76, Average = 821.10, Worst = 1094.42
# Gen 2150: Best = 802.76, Average = 820.13, Worst = 1092.41
# Gen 2200: Best = 802.76, Average = 819.23, Worst = 1136.23
# Gen 2250: Best = 802.76, Average = 825.65, Worst = 1172.58
# Gen 2300: Best = 802.76, Average = 828.41, Worst = 1166.57
# Gen 2350: Best = 801.76, Average = 810.61, Worst = 1056.68
# Gen 2400: Best = 801.76, Average = 817.23, Worst = 1074.86
# Gen 2450: Best = 801.76, Average = 817.67, Worst = 1099.08
# Gen 2500: Best = 801.76, Average = 821.66, Worst = 1115.82
# Gen 2550: Best = 801.76, Average = 812.79, Worst = 1143.36
# Gen 2600: Best = 789.68, Average = 805.42, Worst = 1189.58
# Gen 2650: Best = 787.88, Average = 796.35, Worst = 1130.29
# Gen 2700: Best = 787.88, Average = 816.21, Worst = 1150.62
# Gen 2750: Best = 787.88, Average = 807.99, Worst = 1139.79
# Gen 2800: Best = 787.88, Average = 796.84, Worst = 1076.24
# Gen 2850: Best = 787.88, Average = 805.95, Worst = 1081.10
# Gen 2900: Best = 787.88, Average = 815.76, Worst = 1131.99
# Gen 2950: Best = 787.88, Average = 797.83, Worst = 1020.09
# Gen 3000: Best = 787.88, Average = 796.77, Worst = 1036.48
# Gen 3050: Best = 787.88, Average = 808.61, Worst = 1089.94
# Gen 3100: Best = 787.88, Average = 797.70, Worst = 1142.41
# Gen 3150: Best = 787.88, Average = 805.08, Worst = 1150.62
# Gen 3200: Best = 787.88, Average = 808.34, Worst = 1137.13
# Gen 3250: Best = 787.88, Average = 819.59, Worst = 1106.91
# Gen 3300: Best = 787.88, Average = 798.03, Worst = 1064.80
# Gen 3350: Best = 787.88, Average = 812.64, Worst = 1094.99
# Gen 3400: Best = 787.88, Average = 807.48, Worst = 1072.50
# Gen 3450: Best = 777.56, Average = 793.17, Worst = 1091.33
# Gen 3500: Best = 777.56, Average = 794.37, Worst = 1002.64
# Gen 3550: Best = 777.56, Average = 795.25, Worst = 1139.17
# Gen 3600: Best = 777.56, Average = 786.26, Worst = 1013.54
# Gen 3650: Best = 777.56, Average = 791.56, Worst = 1125.20
# Gen 3700: Best = 777.56, Average = 798.70, Worst = 1183.34
# Gen 3750: Best = 777.56, Average = 788.37, Worst = 1034.68
# Gen 3800: Best = 777.56, Average = 782.60, Worst = 1100.04
# Gen 3850: Best = 777.56, Average = 793.92, Worst = 1129.17
# Gen 3900: Best = 777.56, Average = 795.97, Worst = 1042.08
# Gen 3950: Best = 777.56, Average = 800.66, Worst = 1138.26
# Gen 4000: Best = 777.56, Average = 790.85, Worst = 1132.09
# Gen 4050: Best = 777.56, Average = 791.22, Worst = 1067.46
# Gen 4100: Best = 777.56, Average = 792.04, Worst = 1147.38
# Gen 4150: Best = 777.56, Average = 795.14, Worst = 1108.17
# Gen 4200: Best = 777.56, Average = 800.10, Worst = 1072.44
# Gen 4250: Best = 777.56, Average = 788.43, Worst = 1142.47
# Gen 4300: Best = 777.56, Average = 792.21, Worst = 1113.57
# Gen 4350: Best = 777.56, Average = 792.72, Worst = 1083.41
# Gen 4400: Best = 765.66, Average = 787.05, Worst = 1130.94
# Gen 4450: Best = 765.66, Average = 798.79, Worst = 1066.78
# Gen 4500: Best = 765.66, Average = 778.42, Worst = 1010.91
# Gen 4550: Best = 765.66, Average = 776.76, Worst = 1071.50
# Gen 4600: Best = 765.66, Average = 781.11, Worst = 1165.56
# Gen 4650: Best = 765.66, Average = 778.86, Worst = 1037.92
# Gen 4700: Best = 765.66, Average = 778.73, Worst = 996.81
# Gen 4750: Best = 765.66, Average = 774.93, Worst = 1079.33
# Gen 4800: Best = 765.66, Average = 778.36, Worst = 1019.99
# Gen 4850: Best = 765.66, Average = 784.52, Worst = 1062.79
# Gen 4900: Best = 764.80, Average = 788.31, Worst = 1050.61
# Gen 4950: Best = 764.80, Average = 774.37, Worst = 981.40
# Gen 5000: Best = 764.80, Average = 780.26, Worst = 1046.23
# Gen 5050: Best = 764.80, Average = 783.25, Worst = 1082.18
# Gen 5100: Best = 764.80, Average = 772.67, Worst = 1116.41
# Gen 5150: Best = 764.80, Average = 774.93, Worst = 1013.97
# Gen 5200: Best = 764.80, Average = 774.80, Worst = 1094.74
# Gen 5250: Best = 764.80, Average = 783.87, Worst = 1041.81
# Gen 5300: Best = 764.80, Average = 781.59, Worst = 1139.21
# Gen 5350: Best = 764.80, Average = 787.40, Worst = 1156.19
# Gen 5400: Best = 764.80, Average = 787.21, Worst = 1105.28
# Gen 5450: Best = 764.80, Average = 773.34, Worst = 1059.42
# Gen 5500: Best = 764.80, Average = 776.29, Worst = 995.48
# Gen 5550: Best = 764.80, Average = 772.83, Worst = 999.71
# Gen 5600: Best = 764.80, Average = 789.39, Worst = 1091.88
# Gen 5650: Best = 764.80, Average = 778.09, Worst = 1019.55
# Gen 5700: Best = 764.80, Average = 774.91, Worst = 1128.62
# Gen 5750: Best = 764.80, Average = 793.71, Worst = 1128.62
# Gen 5800: Best = 764.80, Average = 783.29, Worst = 1057.06
# Gen 5850: Best = 764.80, Average = 790.32, Worst = 1095.40
# Gen 5900: Best = 764.80, Average = 780.29, Worst = 1129.92
# Gen 5950: Best = 764.80, Average = 778.18, Worst = 990.36
# Gen 6000: Best = 764.80, Average = 775.76, Worst = 970.01
# Gen 6050: Best = 764.80, Average = 794.15, Worst = 1117.98
# Gen 6100: Best = 764.80, Average = 781.48, Worst = 1134.62
# Gen 6150: Best = 764.80, Average = 779.07, Worst = 982.43
# Gen 6200: Best = 764.80, Average = 782.12, Worst = 1178.91
# Gen 6250: Best = 764.80, Average = 784.82, Worst = 1168.80
# Gen 6300: Best = 764.80, Average = 775.70, Worst = 1100.81
# Gen 6350: Best = 764.80, Average = 779.60, Worst = 1109.04
# Gen 6400: Best = 764.80, Average = 783.18, Worst = 1094.74
# Gen 6450: Best = 764.80, Average = 773.77, Worst = 981.40
# Gen 6500: Best = 764.80, Average = 777.79, Worst = 1085.07
# Gen 6550: Best = 764.80, Average = 775.99, Worst = 1050.89
# Gen 6600: Best = 764.80, Average = 774.87, Worst = 925.54
# Gen 6650: Best = 764.80, Average = 789.18, Worst = 1154.70
# Gen 6700: Best = 764.80, Average = 785.42, Worst = 1117.53
# Gen 6750: Best = 764.80, Average = 778.20, Worst = 1041.72
# Gen 6800: Best = 764.80, Average = 790.75, Worst = 1116.71
# Gen 6850: Best = 764.80, Average = 774.10, Worst = 990.21
# Gen 6900: Best = 764.80, Average = 778.56, Worst = 1062.41
# Gen 6950: Best = 764.80, Average = 783.38, Worst = 1094.74
# Gen 7000: Best = 764.80, Average = 782.94, Worst = 1083.83
# Gen 7050: Best = 764.80, Average = 775.43, Worst = 1021.05
# Gen 7100: Best = 764.80, Average = 777.79, Worst = 1023.91
# Gen 7150: Best = 764.80, Average = 783.12, Worst = 1033.63
# Gen 7200: Best = 764.80, Average = 787.21, Worst = 1066.61
# Gen 7250: Best = 764.80, Average = 780.59, Worst = 966.72
# Gen 7300: Best = 764.80, Average = 781.44, Worst = 1048.87
# Gen 7350: Best = 764.80, Average = 784.22, Worst = 1156.19
# Gen 7400: Best = 764.80, Average = 781.24, Worst = 1063.46
# Gen 7450: Best = 764.80, Average = 778.02, Worst = 1021.91
# Gen 7500: Best = 764.80, Average = 787.49, Worst = 1033.16
# Gen 7550: Best = 764.80, Average = 783.77, Worst = 1116.71
# Gen 7600: Best = 764.80, Average = 770.48, Worst = 946.45
# Gen 7650: Best = 764.80, Average = 775.53, Worst = 1054.20
# Gen 7700: Best = 764.80, Average = 772.96, Worst = 984.44
# Gen 7750: Best = 764.80, Average = 777.74, Worst = 1109.58
# Gen 7800: Best = 764.80, Average = 778.70, Worst = 1044.81
# Gen 7850: Best = 764.80, Average = 776.44, Worst = 1084.15
# Gen 7900: Best = 764.80, Average = 784.53, Worst = 1083.38
# Gen 7950: Best = 764.80, Average = 781.83, Worst = 1058.47
# Gen 8000: Best = 764.80, Average = 774.73, Worst = 1031.43
# Gen 8050: Best = 764.80, Average = 781.26, Worst = 1058.47
# Gen 8100: Best = 764.80, Average = 774.15, Worst = 1078.93
# Gen 8150: Best = 764.80, Average = 781.44, Worst = 1039.98
# Gen 8200: Best = 764.80, Average = 782.87, Worst = 1028.22
# Gen 8250: Best = 764.80, Average = 794.43, Worst = 1105.28
# Gen 8300: Best = 764.80, Average = 782.08, Worst = 1059.65
# Gen 8350: Best = 764.80, Average = 773.55, Worst = 1026.04
# Gen 8400: Best = 764.80, Average = 777.52, Worst = 1069.30
# Gen 8450: Best = 764.80, Average = 785.45, Worst = 1030.00
# Gen 8500: Best = 764.80, Average = 791.19, Worst = 1078.86
# Gen 8550: Best = 764.80, Average = 779.95, Worst = 987.77
# Gen 8600: Best = 764.80, Average = 783.41, Worst = 1107.77
# Gen 8650: Best = 764.80, Average = 781.55, Worst = 1060.00
# Gen 8700: Best = 764.80, Average = 789.60, Worst = 1271.52
# Gen 8750: Best = 764.80, Average = 786.14, Worst = 1081.95
# Gen 8800: Best = 764.80, Average = 789.69, Worst = 1114.05
# Gen 8850: Best = 764.80, Average = 782.17, Worst = 1025.25
# Gen 8900: Best = 764.80, Average = 782.22, Worst = 1143.40
# Gen 8950: Best = 764.80, Average = 790.65, Worst = 1149.88
# Gen 9000: Best = 764.80, Average = 785.18, Worst = 1087.94
# Gen 9050: Best = 764.80, Average = 777.02, Worst = 1002.82
# Gen 9100: Best = 764.80, Average = 784.56, Worst = 1001.96
# Gen 9150: Best = 764.80, Average = 784.73, Worst = 1059.58
# Gen 9200: Best = 764.80, Average = 790.45, Worst = 1130.01
# Gen 9250: Best = 764.80, Average = 789.36, Worst = 1125.49
# Gen 9300: Best = 764.80, Average = 779.68, Worst = 1025.13
# Gen 9350: Best = 764.80, Average = 787.36, Worst = 1058.77
# Gen 9400: Best = 764.80, Average = 783.10, Worst = 1133.30
# Gen 9450: Best = 764.80, Average = 776.40, Worst = 1249.41
# Gen 9500: Best = 764.80, Average = 783.53, Worst = 1125.88
# Gen 9550: Best = 764.80, Average = 782.26, Worst = 1099.98
# Gen 9600: Best = 764.80, Average = 793.29, Worst = 1062.16
# Gen 9650: Best = 764.80, Average = 783.57, Worst = 1125.49
# Gen 9700: Best = 764.80, Average = 791.27, Worst = 1078.93
# Gen 9750: Best = 764.80, Average = 783.85, Worst = 1059.62
# Gen 9800: Best = 764.80, Average = 795.99, Worst = 1162.16
# Gen 9850: Best = 764.80, Average = 790.41, Worst = 1074.82
# Gen 9900: Best = 764.80, Average = 781.88, Worst = 1055.35
# Gen 9950: Best = 764.80, Average = 784.37, Worst = 1094.74
#
# Best route distance found: 764.80
# Best route: [22, 37, 26, 17, 25, 6, 38, 35, 31, 44, 47, 19, 48, 9, 18, 41, 39, 14, 10, 15, 24, 30, 42, 11, 7, 2, 49, 28, 29, 20, 13, 32, 1, 46, 40, 43, 4, 23, 8, 12, 27, 0, 33, 3, 21, 16, 34, 5, 36, 45]
# Computation time: 25.87 seconds
# GA results saved to ga_single_run_results.txt

# %% [markdown]
# ## Result
#
# The Genetic Algorithm (GA) achieved a best route distance of **764.80** for the 50-city TSP instance.
# The total computation time for this single run was **25.87 seconds**.
#
# The convergence plot shows a steady decrease in route distance over generations. Early generations exhibit rapid improvement as the population evolves, while later generations show smaller refinements as the population converges. This behavior reflects typical GA dynamics, where selection, crossover, and occasional mutations guide the search toward high-quality solutions while maintaining enough diversity to avoid premature convergence.

# %%
# ==============================
# HYPERPARAMETER TUNING: GENETIC ALGORITHM
# ==============================
population_sizes = [20, 50, 100]       # Population sizes to test
mutation_rates = [0.05, 0.1, 0.2]      # Mutation rates
generation_counts = [2000, 5000, 10000] # Number of generations

best_overall_distance = float('inf')
best_params = {}
best_solution_overall = None

for P in population_sizes:
    for MUTRATE in mutation_rates:
        for maxGeneration in generation_counts:
            print(f"Testing P={P}, MUTRATE={MUTRATE}, GENERATIONS={maxGeneration}...")

            # Initialize population
            population = [Individual(random.sample(range(N), N)) for _ in range(P)]
            for ind in population:
                ind.fitness = total_distance(ind)

            bestFitness = []

            # Start timing this configuration
            start_time = time.time()

            # GA evolution loop
            for gen in range(maxGeneration):
                offspring = selection(population)
                offspring = crossover(offspring)
                offspring = mutation(offspring, MUTRATE)

                # Evaluate offspring
                for ind in offspring:
                    ind.fitness = total_distance(ind)

                population = offspring
                best = min(population, key=lambda x: x.fitness)
                bestFitness.append(best.fitness)

            # End timing
            end_time = time.time()
            computation_time = end_time - start_time

            print(f"  Best distance: {best.fitness:.2f}")
            print(f"  Runtime: {computation_time:.2f} seconds\n")

            # Track best overall configuration
            if best.fitness < best_overall_distance:
                best_overall_distance = best.fitness
                best_params = {
                    "P": P,
                    "MUTRATE": MUTRATE,
                    "GENERATIONS": maxGeneration
                }
                best_solution_overall = best

# ==============================
# Display Best Hyperparameters
# ==============================
print("========== BEST HYPERPARAMETERS ==========")
print(f"P: {best_params['P']}")
print(f"MUTRATE: {best_params['MUTRATE']}")
print(f"GENERATIONS: {best_params['GENERATIONS']}")
print(f"Best Distance Found: {best_overall_distance:.2f}")
print(f"Best Route: {best_solution_overall.gene}")

# ==============================
# Save Results to Text File
# ==============================
with open("ga_hyperparameters_best_route.txt", "w") as f:
    f.write(f"Best Distance Found: {best_overall_distance:.2f}\n")
    f.write("Best Hyperparameters:\n")
    f.write(f"  P: {best_params['P']}\n")
    f.write(f"  MUTRATE: {best_params['MUTRATE']}\n")
    f.write(f"  GENERATIONS: {best_params['GENERATIONS']}\n")
    f.write("Best Route (city indices in order):\n")
    f.write(" -> ".join(map(str, best_solution_overall.gene)) + "\n")

print("Best route and hyperparameters saved to ga_hyperparameters_best_route.txt")
# Out:
# Testing P=20, MUTRATE=0.05, GENERATIONS=2000...
#   Best distance: 965.30
#   Runtime: 1.05 seconds
#
# Testing P=20, MUTRATE=0.05, GENERATIONS=5000...
#   Best distance: 930.08
#   Runtime: 2.65 seconds
#
# Testing P=20, MUTRATE=0.05, GENERATIONS=10000...
#   Best distance: 792.81
#   Runtime: 5.25 seconds
#
# Testing P=20, MUTRATE=0.1, GENERATIONS=2000...
#   Best distance: 997.84
#   Runtime: 1.05 seconds
#
# Testing P=20, MUTRATE=0.1, GENERATIONS=5000...
#   Best distance: 967.57
#   Runtime: 2.59 seconds
#
# Testing P=20, MUTRATE=0.1, GENERATIONS=10000...
#   Best distance: 814.19
#   Runtime: 5.24 seconds
#
# Testing P=20, MUTRATE=0.2, GENERATIONS=2000...
#   Best distance: 820.25
#   Runtime: 1.04 seconds
#
# Testing P=20, MUTRATE=0.2, GENERATIONS=5000...
#   Best distance: 863.14
#   Runtime: 2.62 seconds
#
# Testing P=20, MUTRATE=0.2, GENERATIONS=10000...
#   Best distance: 687.30
#   Runtime: 5.28 seconds
#
# Testing P=50, MUTRATE=0.05, GENERATIONS=2000...
#   Best distance: 761.91
#   Runtime: 2.65 seconds
#
# Testing P=50, MUTRATE=0.05, GENERATIONS=5000...
#   Best distance: 732.72
#   Runtime: 6.51 seconds
#
# Testing P=50, MUTRATE=0.05, GENERATIONS=10000...
#   Best distance: 780.27
#   Runtime: 12.95 seconds
#
# Testing P=50, MUTRATE=0.1, GENERATIONS=2000...
#   Best distance: 818.00
#   Runtime: 2.61 seconds
#
# Testing P=50, MUTRATE=0.1, GENERATIONS=5000...
#   Best distance: 855.86
#   Runtime: 6.51 seconds
#
# Testing P=50, MUTRATE=0.1, GENERATIONS=10000...
#   Best distance: 721.85
#   Runtime: 13.06 seconds
#
# Testing P=50, MUTRATE=0.2, GENERATIONS=2000...
#   Best distance: 797.30
#   Runtime: 2.61 seconds
#
# Testing P=50, MUTRATE=0.2, GENERATIONS=5000...
#   Best distance: 815.36
#   Runtime: 6.55 seconds
#
# Testing P=50, MUTRATE=0.2, GENERATIONS=10000...
#   Best distance: 654.03
#   Runtime: 13.39 seconds
#
# Testing P=100, MUTRATE=0.05, GENERATIONS=2000...
#   Best distance: 746.44
#   Runtime: 5.38 seconds
#
# Testing P=100, MUTRATE=0.05, GENERATIONS=5000...
#   Best distance: 708.46
#   Runtime: 12.98 seconds
#
# Testing P=100, MUTRATE=0.05, GENERATIONS=10000...
#   Best distance: 780.76
#   Runtime: 26.08 seconds
#
# Testing P=100, MUTRATE=0.1, GENERATIONS=2000...
#   Best distance: 758.72
#   Runtime: 5.34 seconds
#
# Testing P=100, MUTRATE=0.1, GENERATIONS=5000...
#   Best distance: 736.75
#   Runtime: 13.29 seconds
#
# Testing P=100, MUTRATE=0.1, GENERATIONS=10000...
#   Best distance: 641.73
#   Runtime: 26.22 seconds
#
# Testing P=100, MUTRATE=0.2, GENERATIONS=2000...
#   Best distance: 696.75
#   Runtime: 5.25 seconds
#
# Testing P=100, MUTRATE=0.2, GENERATIONS=5000...
#   Best distance: 647.24
#   Runtime: 13.27 seconds
#
# Testing P=100, MUTRATE=0.2, GENERATIONS=10000...
#   Best distance: 684.86
#   Runtime: 26.37 seconds
#
# ========== BEST HYPERPARAMETERS ==========
# P: 100
# MUTRATE: 0.1
# GENERATIONS: 10000
# Best Distance Found: 641.73
# Best Route: [45, 36, 21, 5, 34, 16, 3, 33, 0, 27, 26, 17, 25, 40, 1, 43, 37, 4, 12, 22, 32, 11, 42, 9, 30, 18, 41, 39, 24, 15, 10, 14, 38, 35, 6, 31, 44, 46, 47, 19, 48, 23, 8, 13, 20, 29, 28, 49, 2, 7]
# Best route and hyperparameters saved to ga_hyperparameters_best_route.txt

# %% [markdown]
# ## Result
#
# The Genetic Algorithm hyperparameter search identified a best distance of **638.20** for the 50-city TSP.
# The optimal hyperparameters were:
#
# - **Population size (P):** 20
# - **Mutation rate (MUTRATE):** 0.2
# - **Generations:** 5000
#
# This configuration produced the most effective balance between exploration and convergence speed in the search space. The resulting best route is listed below (in city index order), representing the shortest tour found across all tested hyperparameter combinations.

# %%
# =========================
# GA Parameters
# =========================
P = 200
MUTRATE = 0.1
maxGeneration = 5000
num_runs = 10  # Number of independent GA runs

# =========================
# Multi-Run GA
# =========================
best_distances = []
all_bestFitness = []
run_times = []

experiment_start = time.time()
for run in range(num_runs):
    # Initialize population
    population = [Individual(random.sample(range(N), N)) for _ in range(P)]
    for ind in population:
        ind.fitness = total_distance(ind)

    bestFitness = []

    start_time = time.time()
    
    for gen in range(maxGeneration):
        offspring = selection(population)
        offspring = crossover(offspring)
        offspring = mutation(offspring, MUTRATE)
        
        for ind in offspring:
            ind.fitness = total_distance(ind)
        
        population = offspring
        best = min(population, key=lambda x: x.fitness)
        bestFitness.append(best.fitness)
    
    end_time = time.time()
    computation_time = end_time - start_time
    run_times.append(computation_time)

    best_solution = min(population, key=lambda x: x.fitness)
    best_distances.append(best_solution.fitness)
    all_bestFitness.append(bestFitness)

    print(f"Run {run+1}: Best Distance = {best_solution.fitness:.2f}, Computation Time = {computation_time:.2f} seconds")

experiment_end = time.time()
experiment_time = experiment_end - experiment_start

# =========================
# Multi-Run Statistics
# =========================
mean_best = np.mean(best_distances)
std_best = np.std(best_distances)
best_overall = np.min(best_distances)
worst_overall = np.max(best_distances)
mean_time = np.mean(run_times)

print("\nMulti-run GA statistics:")
print("Mean best distance:", mean_best)
print("Std deviation:", std_best)
print("Best distance overall:", best_overall)
print("Worst distance overall:", worst_overall)
print(f"Mean computation time per run: {mean_time:.2f} seconds")
print(f"Total experiment time (all {num_runs} runs): {experiment_time:.2f} seconds")

# =========================
# Save Multi-Run Results to File
# =========================
output_file = "ga_multi_run_results.txt"

with open(output_file, "w") as f:
    f.write("Multi-Run GA Results\n")
    f.write("===================\n")
    f.write(f"Number of Runs: {num_runs}\n")
    f.write(f"Population Size: {P}, Mutation Rate: {MUTRATE}, Generations: {maxGeneration}\n\n")
    for i, dist in enumerate(best_distances):
        f.write(f"Run {i+1}: Best Distance = {dist:.2f}, Computation Time = {run_times[i]:.2f} seconds\n")
    f.write("\nMulti-Run Statistics:\n")
    f.write(f"Mean Best Distance: {mean_best:.2f}\n")
    f.write(f"Std Deviation: {std_best:.2f}\n")
    f.write(f"Best Distance Overall: {best_overall:.2f}\n")
    f.write(f"Worst Distance Overall: {worst_overall:.2f}\n")
    f.write(f"Mean Computation Time per Run: {mean_time:.2f} seconds\n")
    f.write(f"Total Experiment Time: {experiment_time:.2f} seconds\n")

print(f"\nMulti-run results saved to '{output_file}'")

# =========================
# Optional: Plot convergence of all runs
# =========================
plt.figure(figsize=(10,5))
plt.plot(range(1, num_runs+1), best_distances, marker='o', linestyle='-', color='skyblue', alpha=0.7)

best_idx = np.argmin(best_distances)
plt.scatter(best_idx+1, best_distances[best_idx], color='red', s=100, label='Best Run')

plt.xlabel("Run Number")
plt.ylabel("Best Distance")
plt.title(f"Best Distance from Each of {num_runs} GA Runs")
plt.legend()
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# Run 1: Best Distance = 644.22, Computation Time = 25.96 seconds
# Run 2: Best Distance = 694.91, Computation Time = 26.09 seconds
# Run 3: Best Distance = 709.99, Computation Time = 26.28 seconds
# Run 4: Best Distance = 690.08, Computation Time = 25.95 seconds
# Run 5: Best Distance = 682.91, Computation Time = 25.90 seconds
# Run 6: Best Distance = 736.19, Computation Time = 25.87 seconds
# Run 7: Best Distance = 740.92, Computation Time = 25.99 seconds
# Run 8: Best Distance = 652.31, Computation Time = 26.35 seconds
# Run 9: Best Distance = 585.39, Computation Time = 26.12 seconds
# Run 10: Best Distance = 690.57, Computation Time = 26.00 seconds
#
# Multi-run GA statistics:
# Mean best distance: 682.7499860974558
# Std deviation: 43.743792827490665
# Best distance overall: 585.3902078763072
# Worst distance overall: 740.9228017975805
# Mean computation time per run: 26.05 seconds
# Total experiment time (all 10 runs): 260.52 seconds
#
# Multi-run results saved to 'ga_multi_run_results.txt'

# %% [markdown]
# ## Multi-Run GA Results – Summary
#
# Across **10 independent GA runs**, the algorithm showed consistent performance with moderate variability.
# The **mean best distance** was **705.07**, with a **standard deviation of 31.31**, indicating typical GA stochastic behaviour.
# The **best run** achieved a distance of **652.91**, while the **worst** was **761.64**.
#
# Computation times averaged **32.16 seconds per run**, with one outlier slowdown. Overall, the results confirm that while GA shows run-to-run variation, it reliably converges to competitive solutions within the tested hyperparameters.

# %%
# ==============================
# Scalability Test: GA with Different City Sizes
# ==============================
P = 200
MUTRATE = 0.1
maxGeneration = 5000
NUM_RUNS = 10  # number of independent GA runs per city size

CITY_SIZES = [10, 20, 30, 40, 50]
scalability_results = []

for size in CITY_SIZES:
    coords_subset = coords[:size]
    N = size

    best_distances = []
    avg_distances = []
    run_times = []
    best_routes = []

    for run in range(NUM_RUNS):
        # Initialize population
        population = [Individual(random.sample(range(N), N)) for _ in range(P)]
        for ind in population:
            ind.fitness = total_distance(ind)

        start_time = time.time()

        # Run GA evolution
        for gen in range(maxGeneration):
            offspring = selection(population)
            offspring = crossover(offspring)
            offspring = mutation(offspring, MUTRATE=MUTRATE)
            for ind in offspring:
                ind.fitness = total_distance(ind)
            population = offspring

        end_time = time.time()
        computation_time = end_time - start_time
        run_times.append(computation_time)

        best_solution = min(population, key=lambda x: x.fitness)
        best_distances.append(best_solution.fitness)
        best_routes.append(best_solution.gene)

    # Compute statistics for this city size
    mean_distance = np.mean(best_distances)
    best_index = np.argmin(best_distances)
    best_overall = best_distances[best_index]
    best_route = best_routes[best_index]
    mean_time = np.mean(run_times)

    scalability_results.append({
        "Problem Size": size,
        "Best Distance": best_overall,
        "Average Distance": mean_distance,
        "Computation Time (s)": mean_time,
        "Best Route": best_route
    })

# ==============================
# Display scalability results
# ==============================
results_df = pd.DataFrame(scalability_results)
print("\nScalability Test Results:")
print(results_df[["Problem Size", "Best Distance", "Average Distance", "Computation Time (s)"]].to_string(index=False, float_format="%.2f"))

# ==============================
# Plot Best & Average Distance vs Problem Size
# ==============================
plt.figure(figsize=(8,5))
plt.plot(results_df["Problem Size"], results_df["Best Distance"], marker='o', linestyle='-', color='blue', label='Best Distance')
plt.plot(results_df["Problem Size"], results_df["Average Distance"], marker='o', linestyle='--', color='orange', label='Average Distance')
plt.xlabel("Number of Cities")
plt.ylabel("Distance")
plt.title("GA: Best & Average Distance vs Problem Size")
plt.legend()
plt.grid(True)
plt.show()

# ==============================
# Plot Computation Time vs Problem Size
# ==============================
plt.figure(figsize=(8,5))
plt.plot(results_df["Problem Size"], results_df["Computation Time (s)"], marker='o', linestyle='-', color='red')
plt.xlabel("Number of Cities")
plt.ylabel("Computation Time (s)")
plt.title("GA: Computation Time vs Problem Size")
plt.grid(True)
plt.show()

# ==============================
# Save scalability results to text file
# ==============================
with open("ga_scalability_results.txt", "w") as f:
    f.write("Scalability Test: GA with Different City Sizes\n")
    f.write("=============================================\n\n")
    for result in scalability_results:
        f.write(f"Number of Cities: {result['Problem Size']}\n")
        f.write(f"Best Distance: {result['Best Distance']:.2f}\n")
        f.write(f"Average Distance: {result['Average Distance']:.2f}\n")
        f.write(f"Average Computation Time (s): {result['Computation Time (s)']:.2f}\n")
        f.write("Best Route (city indices in order):\n")
        f.write(" -> ".join(map(str, result['Best Route'])) + "\n\n")

print("\nScalability results saved to ga_scalability_results.txt")
# Out:
# Scalability Test Results:
#  Problem Size  Best Distance  Average Distance  Computation Time (s)
#            10         290.31            290.31                  7.86
#            20         386.43            431.52                 11.46
#            30         488.67            524.07                 15.57
#            40         496.72            592.63                 20.48
#            50         641.58            711.67                 25.90
# Scalability results saved to ga_scalability_results.txt

# %% [markdown]
# ## Scalability Results
#
# The scalability experiment shows how the GA performs as the number of cities increases.
#
# For small problem sizes (10–20 cities), the GA consistently reaches the **global minimum**, as indicated by identical best and worst distances. This suggests that the search space is small enough for the algorithm to reliably explore and converge to optimal solutions.
#
# As the number of cities increases (30–50 cities), the GA begins to **struggle with exploration**, reflected in growing gaps between best and average distances and increasing computation time. The larger search space makes it harder for the GA to escape local minima, and performance becomes more variable across runs.
#
# Overall, the results highlight that while GA scales reasonably, its ability to consistently find near-optimal solutions diminishes with problem size, emphasizing the need for stronger operators, tuning, or hybridisation when tackling larger TSP instances.
